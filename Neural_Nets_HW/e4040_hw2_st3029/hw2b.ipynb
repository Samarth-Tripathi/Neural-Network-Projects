# %% [markdown]
# ## ECBM 4040 HW 2 (b) 1.

# %% [markdown]
# # ECBM 4040 HW 2 (b) 2.
#
# Comparison between activations Tanh and softmax for 2 hidden layers of 500 neurons each.
#
# The other parameters are - learning_rate=0.01, L1_reg=0.00, L2_reg=0.0001, n_epochs=100, batch_size=20

# %%
from hw2b import *

test_mlp(n_hidden_list=[500,500], h_activations=[T.tanh,T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [500, 500]
# ... training
# epoch 1, minibatch 3296/3296, validation error 80.710383 %
#      epoch 1, minibatch 3296/3296, test error of best model 79.938509 %
# epoch 2, minibatch 3296/3296, validation error 61.543716 %
#      epoch 2, minibatch 3296/3296, test error of best model 61.425826 %
# epoch 3, minibatch 3296/3296, validation error 49.603825 %
#      epoch 3, minibatch 3296/3296, test error of best model 52.252114 %
# epoch 4, minibatch 3296/3296, validation error 43.251366 %
#      epoch 4, minibatch 3296/3296, test error of best model 45.814758 %
# epoch 5, minibatch 3296/3296, validation error 40.218579 %
#      epoch 5, minibatch 3296/3296, test error of best model 42.651806 %
# epoch 6, minibatch 3296/3296, validation error 38.620219 %
#      epoch 6, minibatch 3296/3296, test error of best model 40.518832 %
# epoch 7, minibatch 3296/3296, validation error 36.120219 %
# ...

# %%
from hw2b import *

test_mlp(n_hidden_list=[500,500], h_activations=[T.nnet.softmax,T.nnet.softmax])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [500, 500]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.161202 %
# epoch 4, minibatch 3296/3296, validation error 81.161202 %
# epoch 5, minibatch 3296/3296, validation error 81.161202 %
# epoch 6, minibatch 3296/3296, validation error 81.161202 %
# epoch 7, minibatch 3296/3296, validation error 81.161202 %
# epoch 8, minibatch 3296/3296, validation error 81.161202 %
# epoch 9, minibatch 3296/3296, validation error 81.161202 %
# epoch 10, minibatch 3296/3296, validation error 81.161202 %
# epoch 11, minibatch 3296/3296, validation error 81.161202 %
# epoch 12, minibatch 3296/3296, validation error 81.161202 %
# epoch 13, minibatch 3296/3296, validation error 81.161202 %
# ...

# %% [markdown]
# # ECBM 4040 HW 2 (b) 3.

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=100,batch_size=20,n_hidden_list=[300,300,300], h_activations=[T.tanh,T.tanh,T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [300, 300, 300]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.161202 %
# epoch 4, minibatch 3296/3296, validation error 80.997268 %
#      epoch 4, minibatch 3296/3296, test error of best model 80.445811 %
# epoch 5, minibatch 3296/3296, validation error 80.614754 %
#      epoch 5, minibatch 3296/3296, test error of best model 80.380477 %
# epoch 6, minibatch 3296/3296, validation error 79.972678 %
#      epoch 6, minibatch 3296/3296, test error of best model 79.923136 %
# epoch 7, minibatch 3296/3296, validation error 79.357923 %
#      epoch 7, minibatch 3296/3296, test error of best model 79.004612 %
# epoch 8, minibatch 3296/3296, validation error 78.538251 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=100,batch_size=20,n_hidden_list=[300,300,300,300,300], h_activations=[T.tanh,T.tanh,T.tanh,T.tanh,T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [300, 300, 300, 300, 300]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.161202 %
# epoch 4, minibatch 3296/3296, validation error 81.106557 %
#      epoch 4, minibatch 3296/3296, test error of best model 80.622598 %
# epoch 5, minibatch 3296/3296, validation error 80.655738 %
#      epoch 5, minibatch 3296/3296, test error of best model 80.453497 %
# epoch 6, minibatch 3296/3296, validation error 79.877049 %
#      epoch 6, minibatch 3296/3296, test error of best model 79.400461 %
# epoch 7, minibatch 3296/3296, validation error 78.579235 %
#      epoch 7, minibatch 3296/3296, test error of best model 77.363566 %
# epoch 8, minibatch 3296/3296, validation error 73.620219 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=100,batch_size=20,n_hidden_list=[300,300,300,300,300,300,300], h_activations=[T.tanh,T.tanh,T.tanh,T.tanh,T.tanh,T.tanh,T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [300, 300, 300, 300, 300, 300, 300]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.161202 %
# epoch 4, minibatch 3296/3296, validation error 80.942623 %
#      epoch 4, minibatch 3296/3296, test error of best model 80.426595 %
# epoch 5, minibatch 3296/3296, validation error 80.286885 %
#      epoch 5, minibatch 3296/3296, test error of best model 79.730976 %
# epoch 6, minibatch 3296/3296, validation error 78.224044 %
#      epoch 6, minibatch 3296/3296, test error of best model 76.675634 %
# epoch 7, minibatch 3296/3296, validation error 71.816940 %
#      epoch 7, minibatch 3296/3296, test error of best model 72.336664 %
# epoch 8, minibatch 3296/3296, validation error 68.237705 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=100,batch_size=20,n_hidden_list=[300], h_activations=[T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [300]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.106557 %
#      epoch 3, minibatch 3296/3296, test error of best model 80.395849 %
# epoch 4, minibatch 3296/3296, validation error 80.724044 %
#      epoch 4, minibatch 3296/3296, test error of best model 80.253651 %
# epoch 5, minibatch 3296/3296, validation error 80.081967 %
#      epoch 5, minibatch 3296/3296, test error of best model 80.046118 %
# epoch 6, minibatch 3296/3296, validation error 79.822404 %
#      epoch 6, minibatch 3296/3296, test error of best model 79.730976 %
# epoch 7, minibatch 3296/3296, validation error 79.590164 %
#      epoch 7, minibatch 3296/3296, test error of best model 79.442736 %
# ...

# %% [markdown]
# # ECBM 4040 HW 2 (d) 4.

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=250,batch_size=20,n_hidden_list=[840], h_activations=[T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [840]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.024590 %
#      epoch 2, minibatch 3296/3296, test error of best model 80.342045 %
# epoch 3, minibatch 3296/3296, validation error 80.519126 %
#      epoch 3, minibatch 3296/3296, test error of best model 80.119139 %
# epoch 4, minibatch 3296/3296, validation error 79.972678 %
#      epoch 4, minibatch 3296/3296, test error of best model 79.642583 %
# epoch 5, minibatch 3296/3296, validation error 79.357923 %
#      epoch 5, minibatch 3296/3296, test error of best model 79.269792 %
# epoch 6, minibatch 3296/3296, validation error 78.893443 %
#      epoch 6, minibatch 3296/3296, test error of best model 78.854727 %
# epoch 7, minibatch 3296/3296, validation error 78.237705 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=250,batch_size=20,n_hidden_list=[420,420], h_activations=[T.tanh,T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [420, 420]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.174863 %
# epoch 3, minibatch 3296/3296, validation error 81.038251 %
#      epoch 3, minibatch 3296/3296, test error of best model 80.422752 %
# epoch 4, minibatch 3296/3296, validation error 80.765027 %
#      epoch 4, minibatch 3296/3296, test error of best model 80.226749 %
# epoch 5, minibatch 3296/3296, validation error 80.355191 %
#      epoch 5, minibatch 3296/3296, test error of best model 80.049962 %
# epoch 6, minibatch 3296/3296, validation error 79.972678 %
#      epoch 6, minibatch 3296/3296, test error of best model 79.669485 %
# epoch 7, minibatch 3296/3296, validation error 79.275956 %
#      epoch 7, minibatch 3296/3296, test error of best model 79.173713 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=250,batch_size=20,n_hidden_list=[280,280,280], h_activations=[T.tanh,T.tanh,T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [280, 280, 280]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.161202 %
# epoch 4, minibatch 3296/3296, validation error 81.133880 %
#      epoch 4, minibatch 3296/3296, test error of best model 80.430438 %
# epoch 5, minibatch 3296/3296, validation error 81.147541 %
# epoch 6, minibatch 3296/3296, validation error 80.737705 %
#      epoch 6, minibatch 3296/3296, test error of best model 80.441968 %
# epoch 7, minibatch 3296/3296, validation error 80.150273 %
#      epoch 7, minibatch 3296/3296, test error of best model 79.773251 %
# epoch 8, minibatch 3296/3296, validation error 79.316940 %
#      epoch 8, minibatch 3296/3296, test error of best model 78.866257 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=250,batch_size=20,n_hidden_list=[210,210,210,210], h_activations=[T.tanh,T.tanh,T.tanh,T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [210, 210, 210, 210]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.161202 %
# epoch 4, minibatch 3296/3296, validation error 81.161202 %
# epoch 5, minibatch 3296/3296, validation error 81.133880 %
#      epoch 5, minibatch 3296/3296, test error of best model 80.422752 %
# epoch 6, minibatch 3296/3296, validation error 80.683060 %
#      epoch 6, minibatch 3296/3296, test error of best model 80.349731 %
# epoch 7, minibatch 3296/3296, validation error 80.245902 %
#      epoch 7, minibatch 3296/3296, test error of best model 79.550346 %
# epoch 8, minibatch 3296/3296, validation error 79.344262 %
#      epoch 8, minibatch 3296/3296, test error of best model 78.512683 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=250,batch_size=20,n_hidden_list=[168,168,168,168,168], h_activations=[T.tanh,T.tanh,T.tanh,T.tanh,T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [168, 168, 168, 168, 168]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.161202 %
# epoch 4, minibatch 3296/3296, validation error 81.147541 %
#      epoch 4, minibatch 3296/3296, test error of best model 80.484243 %
# epoch 5, minibatch 3296/3296, validation error 80.983607 %
#      epoch 5, minibatch 3296/3296, test error of best model 80.318985 %
# epoch 6, minibatch 3296/3296, validation error 80.587432 %
#      epoch 6, minibatch 3296/3296, test error of best model 79.542659 %
# epoch 7, minibatch 3296/3296, validation error 79.071038 %
#      epoch 7, minibatch 3296/3296, test error of best model 77.413528 %
# epoch 8, minibatch 3296/3296, validation error 74.002732 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=250,batch_size=20,n_hidden_list=[140,140,140,140,140,140], h_activations=[T.tanh,T.tanh,T.tanh,T.tanh,T.tanh,T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [140, 140, 140, 140, 140, 140]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.161202 %
# epoch 4, minibatch 3296/3296, validation error 81.161202 %
# epoch 5, minibatch 3296/3296, validation error 81.161202 %
# epoch 6, minibatch 3296/3296, validation error 80.874317 %
#      epoch 6, minibatch 3296/3296, test error of best model 79.996157 %
# epoch 7, minibatch 3296/3296, validation error 79.699454 %
#      epoch 7, minibatch 3296/3296, test error of best model 78.235972 %
# epoch 8, minibatch 3296/3296, validation error 77.486339 %
#      epoch 8, minibatch 3296/3296, test error of best model 75.418909 %
# epoch 9, minibatch 3296/3296, validation error 73.073770 %
# ...

# %% [markdown]
# # ECBM 4040 HW 2 (d) 5.

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=150,batch_size=20,n_hidden_list=[100], h_activations=[T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [100]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.161202 %
# epoch 4, minibatch 3296/3296, validation error 81.147541 %
#      epoch 4, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 5, minibatch 3296/3296, validation error 81.106557 %
#      epoch 5, minibatch 3296/3296, test error of best model 80.361261 %
# epoch 6, minibatch 3296/3296, validation error 80.956284 %
#      epoch 6, minibatch 3296/3296, test error of best model 80.276710 %
# epoch 7, minibatch 3296/3296, validation error 80.765027 %
#      epoch 7, minibatch 3296/3296, test error of best model 80.134512 %
# epoch 8, minibatch 3296/3296, validation error 80.232240 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=150,batch_size=20,n_hidden_list=[300], h_activations=[T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [300]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.161202 %
# epoch 3, minibatch 3296/3296, validation error 81.106557 %
#      epoch 3, minibatch 3296/3296, test error of best model 80.395849 %
# epoch 4, minibatch 3296/3296, validation error 80.724044 %
#      epoch 4, minibatch 3296/3296, test error of best model 80.253651 %
# epoch 5, minibatch 3296/3296, validation error 80.081967 %
#      epoch 5, minibatch 3296/3296, test error of best model 80.046118 %
# epoch 6, minibatch 3296/3296, validation error 79.822404 %
#      epoch 6, minibatch 3296/3296, test error of best model 79.730976 %
# epoch 7, minibatch 3296/3296, validation error 79.590164 %
#      epoch 7, minibatch 3296/3296, test error of best model 79.442736 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=150,batch_size=20,n_hidden_list=[500], h_activations=[T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [500]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.120219 %
#      epoch 2, minibatch 3296/3296, test error of best model 80.422752 %
# epoch 3, minibatch 3296/3296, validation error 80.833333 %
#      epoch 3, minibatch 3296/3296, test error of best model 80.315142 %
# epoch 4, minibatch 3296/3296, validation error 80.300546 %
#      epoch 4, minibatch 3296/3296, test error of best model 80.111453 %
# epoch 5, minibatch 3296/3296, validation error 79.918033 %
#      epoch 5, minibatch 3296/3296, test error of best model 79.754035 %
# epoch 6, minibatch 3296/3296, validation error 79.562842 %
#      epoch 6, minibatch 3296/3296, test error of best model 79.335127 %
# epoch 7, minibatch 3296/3296, validation error 79.071038 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=150,batch_size=20,n_hidden_list=[700], h_activations=[T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [700]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.010929 %
#      epoch 2, minibatch 3296/3296, test error of best model 80.392006 %
# epoch 3, minibatch 3296/3296, validation error 80.628415 %
#      epoch 3, minibatch 3296/3296, test error of best model 80.176787 %
# epoch 4, minibatch 3296/3296, validation error 80.081967 %
#      epoch 4, minibatch 3296/3296, test error of best model 79.857802 %
# epoch 5, minibatch 3296/3296, validation error 79.576503 %
#      epoch 5, minibatch 3296/3296, test error of best model 79.488855 %
# epoch 6, minibatch 3296/3296, validation error 79.166667 %
#      epoch 6, minibatch 3296/3296, test error of best model 78.981553 %
# epoch 7, minibatch 3296/3296, validation error 78.524590 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=150,batch_size=20,n_hidden_list=[840], h_activations=[T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [840]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.024590 %
#      epoch 2, minibatch 3296/3296, test error of best model 80.342045 %
# epoch 3, minibatch 3296/3296, validation error 80.519126 %
#      epoch 3, minibatch 3296/3296, test error of best model 80.119139 %
# epoch 4, minibatch 3296/3296, validation error 79.972678 %
#      epoch 4, minibatch 3296/3296, test error of best model 79.642583 %
# epoch 5, minibatch 3296/3296, validation error 79.357923 %
#      epoch 5, minibatch 3296/3296, test error of best model 79.269792 %
# epoch 6, minibatch 3296/3296, validation error 78.893443 %
#      epoch 6, minibatch 3296/3296, test error of best model 78.854727 %
# epoch 7, minibatch 3296/3296, validation error 78.237705 %
# ...

# %%
from hw2b import *

test_mlp(learning_rate=0.001, L1_reg=0.00, L2_reg=0.0001, n_epochs=150,batch_size=20,n_hidden_list=[1000], h_activations=[T.tanh])
# Out:
# ... loading data
# complete loading
# ... building the model
# hidden Layers = [1000]
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.415065 %
# epoch 2, minibatch 3296/3296, validation error 81.051913 %
#      epoch 2, minibatch 3296/3296, test error of best model 80.345888 %
# epoch 3, minibatch 3296/3296, validation error 80.519126 %
#      epoch 3, minibatch 3296/3296, test error of best model 80.084550 %
# epoch 4, minibatch 3296/3296, validation error 79.890710 %
#      epoch 4, minibatch 3296/3296, test error of best model 79.665642 %
# epoch 5, minibatch 3296/3296, validation error 79.166667 %
#      epoch 5, minibatch 3296/3296, test error of best model 79.108378 %
# epoch 6, minibatch 3296/3296, validation error 78.497268 %
#      epoch 6, minibatch 3296/3296, test error of best model 78.597233 %
# epoch 7, minibatch 3296/3296, validation error 77.759563 %
# ...
