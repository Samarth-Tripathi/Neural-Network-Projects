# %% [markdown]
# ## ECBM 4040 HW 2 (c) 1.

# %%
from hw2c import *

test_mlp_dropout(0.01,0.00,0.0001,500,20,500,0.7,True,2)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 81.161202 %
#      epoch 1, minibatch 3296/3296, test error of best model 80.418909 %
# epoch 2, minibatch 3296/3296, validation error 76.311475 %
#      epoch 2, minibatch 3296/3296, test error of best model 75.553420 %
# epoch 3, minibatch 3296/3296, validation error 61.256831 %
#      epoch 3, minibatch 3296/3296, test error of best model 60.115296 %
# epoch 4, minibatch 3296/3296, validation error 52.377049 %
#      epoch 4, minibatch 3296/3296, test error of best model 53.378171 %
# epoch 5, minibatch 3296/3296, validation error 44.767760 %
#      epoch 5, minibatch 3296/3296, test error of best model 47.052267 %
# epoch 6, minibatch 3296/3296, validation error 38.866120 %
#      epoch 6, minibatch 3296/3296, test error of best model 41.810146 %
# epoch 7, minibatch 3296/3296, validation error 38.838798 %
# ...

# %%
from hw2c import *

test_mlp_dropout(0.01,0.00,0.0001,500,20,500,1.0,True,2)
# Out:
# ... loading data
# ... building the model
# ... training
# epoch 1, minibatch 3296/3296, validation error 66.024590 %
#      epoch 1, minibatch 3296/3296, test error of best model 63.439662 %
# epoch 2, minibatch 3296/3296, validation error 51.584699 %
#      epoch 2, minibatch 3296/3296, test error of best model 51.529593 %
# epoch 3, minibatch 3296/3296, validation error 41.530055 %
#      epoch 3, minibatch 3296/3296, test error of best model 43.470407 %
# epoch 4, minibatch 3296/3296, validation error 37.568306 %
#      epoch 4, minibatch 3296/3296, test error of best model 39.769408 %
# epoch 5, minibatch 3296/3296, validation error 34.412568 %
#      epoch 5, minibatch 3296/3296, test error of best model 36.325903 %
# epoch 6, minibatch 3296/3296, validation error 32.049180 %
#      epoch 6, minibatch 3296/3296, test error of best model 33.731745 %
# epoch 7, minibatch 3296/3296, validation error 30.601093 %
# ...
