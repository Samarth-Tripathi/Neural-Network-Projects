# %% [markdown]
# ## ECBM E4040 Homework 4 - Programming Problem

# %%
import theano
import hw4a
import hw4b

# %% [markdown]
# ### Problem a: Recurrent Neural Network
# #### Bullet 1: Experiment with RNNSLU

# %%
from hw4a import test_rnnslu
test_rnnslu()
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# verbose: True
# normal: True
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 60
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ...
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 68.18 best test F1 66.22
# NEW BEST: epoch 1 valid F1 80.63 best test F1 77.98
# NEW BEST: epoch 2 valid F1 83.79 best test F1 80.66
# NEW BEST: epoch 3 valid F1 88.42 best test F1 84.92
# NEW BEST: epoch 4 valid F1 89.65 best test F1 85.97
# NEW BEST: epoch 5 valid F1 91.02 best test F1 86.87
# ...

# %%
from hw4a import test_rnnslu
test_rnnslu(win=11)
# Out:
# verbose: True
# normal: True
# win: 11
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 60
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 68.68 best test F1 64.92
# NEW BEST: epoch 1 valid F1 79.32 best test F1 75.92
# NEW BEST: epoch 2 valid F1 83.2 best test F1 80.09
# NEW BEST: epoch 3 valid F1 87.1 best test F1 83.85
# NEW BEST: epoch 4 valid F1 89.61 best test F1 85.38
# NEW BEST: epoch 5 valid F1 90.95 best test F1 87.15
# NEW BEST: epoch 6 valid F1 91.74 best test F1 88.42
# NEW BEST: epoch 7 valid F1 93.77 best test F1 90.66
# NEW BEST: epoch 8 valid F1 94.07 best test F1 90.74
# NEW BEST: epoch 9 valid F1 94.7 best test F1 91.66
# NEW BEST: epoch 10 valid F1 94.97 best test F1 91.02
# NEW BEST: epoch 11 valid F1 95.54 best test F1 92.1
# NEW BEST: epoch 12 valid F1 95.69 best test F1 92.39
# ...

# %%
from hw4a import test_rnnslu
test_rnnslu(win=5)
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# verbose: True
# normal: True
# win: 5
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 60
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 69.47 best test F1 65.79
# NEW BEST: epoch 1 valid F1 80.18 best test F1 76.07
# NEW BEST: epoch 2 valid F1 82.58 best test F1 79.6
# NEW BEST: epoch 3 valid F1 87.23 best test F1 83.35
# NEW BEST: epoch 4 valid F1 89.3 best test F1 85.58
# NEW BEST: epoch 5 valid F1 90.55 best test F1 87.2
#
# ...

# %%
from hw4a import test_rnnslu
test_rnnslu(emb_dimension=100)
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# verbose: True
# normal: True
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 100
# nepochs: 60
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 71.53 best test F1 67.86
# NEW BEST: epoch 1 valid F1 81.24 best test F1 78.63
# NEW BEST: epoch 2 valid F1 84.62 best test F1 81.91
# NEW BEST: epoch 3 valid F1 88.65 best test F1 84.7
# NEW BEST: epoch 4 valid F1 89.71 best test F1 86.27
# NEW BEST: epoch 5 valid F1 91.82 best test F1 87.68
#
# ...

# %% [markdown]
# #### Bullet 2: Experiment with RNNSLU without normalizing word embeddings

# %%
from hw4a import test_rnnslu
test_rnnslu(normal=False)
# Out:
# verbose: True
# normal: False
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 60
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 68.96 best test F1 63.35
# NEW BEST: epoch 1 valid F1 81.28 best test F1 76.9
# NEW BEST: epoch 2 valid F1 84.73 best test F1 81.46
# NEW BEST: epoch 3 valid F1 88.04 best test F1 84.06
# NEW BEST: epoch 4 valid F1 90.05 best test F1 86.02
# NEW BEST: epoch 5 valid F1 91.31 best test F1 86.93
# NEW BEST: epoch 6 valid F1 92.65 best test F1 88.75
# NEW BEST: epoch 7 valid F1 93.21 best test F1 89.79
# NEW BEST: epoch 8 valid F1 94.0 best test F1 90.6
# NEW BEST: epoch 9 valid F1 94.86 best test F1 90.68
# NEW BEST: epoch 10 valid F1 95.13 best test F1 91.98
#
# NEW BEST: epoch 12 valid F1 95.68 best test F1 92.92
# NEW BEST: epoch 13 valid F1 95.91 best test F1 92.79
#
# ...

# %% [markdown]
# #### Bullet 3: Implement RNN with two hidden layers

# %%
from hw4a import test_rnnslu2
test_rnnslu2()
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# verbose: True
# normal: True
# nhidden2: 100
# win: 7
# nhidden1: 200
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 60
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 0.0 best test F1 0.0
# NEW BEST: epoch 1 valid F1 40.95 best test F1 37.18
# NEW BEST: epoch 2 valid F1 52.85 best test F1 48.92
# NEW BEST: epoch 3 valid F1 55.6 best test F1 49.73
# NEW BEST: epoch 4 valid F1 56.95 best test F1 50.54
# NEW BEST: epoch 5 valid F1 62.65 best test F1 59.11
# ...

# %% [markdown]
# #### Bullet 4: Experiment with layer normalization

# %%
from hw4a import test_rnnslu3
test_rnnslu3(nepochs= 30)
# Out:
# verbose: True
# normal: True
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 30
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 68.27 best test F1 64.49
# NEW BEST: epoch 1 valid F1 82.63 best test F1 79.4
# NEW BEST: epoch 2 valid F1 87.14 best test F1 84.07
# NEW BEST: epoch 3 valid F1 90.79 best test F1 87.94
#
# NEW BEST: epoch 5 valid F1 93.75 best test F1 90.08
#
# NEW BEST: epoch 7 valid F1 94.62 best test F1 92.33
# NEW BEST: epoch 8 valid F1 95.25 best test F1 92.16
# NEW BEST: epoch 9 valid F1 95.69 best test F1 92.91
#
# NEW BEST: epoch 11 valid F1 96.19 best test F1 93.78
# NEW BEST: epoch 12 valid F1 96.38 best test F1 93.66
#
#
# NEW BEST: epoch 15 valid F1 96.63 best test F1 93.87
#
# NEW BEST: epoch 17 valid F1 96.69 best test F1 93.8
# NEW BEST: epoch 18 valid F1 96.72 best test F1 94.05
#
# ...

# %%
from hw4a import test_rnnslu3
test_rnnslu3(nepochs= 30, win=11)
# Out:
# verbose: True
# normal: True
# win: 11
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 30
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 64.67 best test F1 59.98
# NEW BEST: epoch 1 valid F1 81.49 best test F1 76.74
# NEW BEST: epoch 2 valid F1 86.16 best test F1 82.2
# NEW BEST: epoch 3 valid F1 89.13 best test F1 85.37
# NEW BEST: epoch 4 valid F1 91.47 best test F1 87.43
# NEW BEST: epoch 5 valid F1 92.91 best test F1 89.72
# NEW BEST: epoch 6 valid F1 92.99 best test F1 90.0
# NEW BEST: epoch 7 valid F1 94.8 best test F1 92.57
# NEW BEST: epoch 8 valid F1 94.89 best test F1 92.58
# NEW BEST: epoch 9 valid F1 95.18 best test F1 93.23
# NEW BEST: epoch 10 valid F1 95.36 best test F1 92.49
# NEW BEST: epoch 11 valid F1 95.64 best test F1 92.92
# NEW BEST: epoch 12 valid F1 96.16 best test F1 93.75
# ...

# %%
from hw4a import test_rnnslu3
test_rnnslu3(nepochs= 20, emb_dimension=100)
# Out:
# verbose: True
# normal: True
# win: 7
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 100
# nepochs: 20
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 69.23 best test F1 65.52
# NEW BEST: epoch 1 valid F1 83.9 best test F1 81.02
# NEW BEST: epoch 2 valid F1 88.86 best test F1 85.48
# NEW BEST: epoch 3 valid F1 91.41 best test F1 87.9
# NEW BEST: epoch 4 valid F1 92.37 best test F1 89.41
# NEW BEST: epoch 5 valid F1 94.02 best test F1 90.59
#
# NEW BEST: epoch 7 valid F1 94.91 best test F1 92.33
# NEW BEST: epoch 8 valid F1 94.92 best test F1 93.08
# NEW BEST: epoch 9 valid F1 95.1 best test F1 93.2
# NEW BEST: epoch 10 valid F1 95.81 best test F1 93.08
# NEW BEST: epoch 11 valid F1 96.04 best test F1 93.67
#
# NEW BEST: epoch 13 valid F1 96.16 best test F1 93.69
#
# NEW BEST: epoch 15 valid F1 96.19 best test F1 93.89
# ...

# %% [markdown]
# #### Bullet 5: Observation on embedding pairs

# %%
from hw4a import test_rnnslu3
test_rnnslu3(nepochs= 20, win=5)
# Out:
# verbose: True
# normal: True
# win: 5
# savemodel: False
# fold: 3
# seed: 345
# emb_dimension: 50
# nepochs: 20
# nhidden: 200
# decay: True
# lr: 0.0970806646813
# folder: ../result
# ... loading the dataset
# ... building the model
# ... training
# NEW BEST: epoch 0 valid F1 68.93 best test F1 65.76
# NEW BEST: epoch 1 valid F1 82.88 best test F1 79.55
# NEW BEST: epoch 2 valid F1 87.03 best test F1 84.76
# NEW BEST: epoch 3 valid F1 89.93 best test F1 86.68
# NEW BEST: epoch 4 valid F1 91.27 best test F1 87.83

# %%
tomorrow - today = tuesday - monday,
rates - rate = prices - price

# %% [markdown]
# ### Problem b: Learning Parity Function
# #### Bullet 1: Shallow MLP

# %%
from hw4b import test_mlp_parity
test_mlp_parity(n_bit=8,n_hidden=100,n_hiddenLayers=1, epoch=30000, learning_rate=0.1, batch_size=64, L1=0.00, L2=0.0001)
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# ... building the model
# Optimization complete.
# Best validation score of 0.446429 % obtained at iteration 61965, with test performance 0.000000 %
# The training process for function test_mlp_parity ran for 5.42m

# %%
from hw4b import test_mlp_parity
test_mlp_parity(n_bit=12,n_hidden=5,n_hiddenLayers=1, epoch=100000, learning_rate=0.1, batch_size=20, L1=0.00, L2=0.0001)
# Out:
# ... building the model
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c2cd10464f47> in <module>()
#       1 from hw4b import test_mlp_parity
# ----> 2 test_mlp_parity(n_bit=12,n_hidden=5,n_hiddenLayers=1, epoch=100000, learning_rate=0.1, batch_size=20, L1=0.00, L2=0.0001)
#
# /home/ubuntu/hw4/e4040_hw4_st3029/src/hw4b.pyc in test_mlp_parity(n_bit, n_hidden, n_hiddenLayers, epoch, learning_rate, batch_size, L1, L2)
#     453     train_nn2(train_model, validate_model, test_model,
#     454             n_train_batches, n_valid_batches, n_test_batches, n_epochs,
# --> 455             verbose = False)
#     456
#     457
#
# /home/ubuntu/hw4/e4040_hw4_st3029/src/hw4b.pyc in train_nn2(train_model, validate_model, test_model, n_train_batches, n_valid_batches, n_test_batches, n_epochs, verbose)
#      83             if (iter % 100 == 0) and verbose:
# ...

# %% [markdown]
# #### Bullet 2: Deep MLP

# %%
from hw4b import test_mlp_parity
test_mlp_parity(n_bit=8,n_hidden=50,n_hiddenLayers=5, epoch=35000, learning_rate=0.1, batch_size=64, L1=0.00, L2=0.0001)
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# ... building the model
# 10000
# 20000
# 30000
# Optimization complete.
# Best validation score of 0.000000 % obtained at iteration 3390, with test performance 1.562500 %
# The training process for function test_mlp_parity ran for 14.11m

# %%
from hw4b import test_mlp_parity
test_mlp_parity(n_bit=12,n_hidden=50,n_hiddenLayers=4, epoch=50000, learning_rate=0.05, batch_size=32, L1=0.0001, L2=0.0001)
# Out:
# Using gpu device 0: GRID K520 (CNMeM is disabled, cuDNN Version is too old. Update to v5, was 3007.)
# /home/ubuntu/miniconda2/envs/theano/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# ... building the model
# 10000
# 20000
# 30000
# Optimization complete.
# Best validation score of 0.625000 % obtained at iteration 23715, with test performance 0.000000 %
# The training process for function test_mlp_parity ran for 27.25m

# %% [markdown]
# #### Bullet 3: RNN

# %% [markdown]
# #### Bullet 4: LSTM
